# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - etc
#
# Note that `metadata_test.csv` and `metadata_train.csv` are generated by the following block of code

# %% [markdown]
# ```
# import pandas as pd
# from pathlib import Path
# from sklearn.model_selection import train_test_split
#
# dir_path = Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/dev_256")
# df_meta = pd.read_csv(f"{dir_path}/metadata.csv")
# df_meta['img_name'] = df_meta['img_path'].str[-13:]
# df_train, df_test = train_test_split(df_meta, test_size=0.2)
# df_train.to_csv(f"{dir_path}/metadata_train.csv")
# df_test.to_csv(f"{dir_path}/metadata_test.csv")
# ```

# %%
from model_vit import *

# %%
CONFIG = {
    'epoch': 2,
    'batch_size': 16,
    'new_vit_model': True,
    'pretrained_model_name': "google/vit-base-patch16-224", # for 'new_vit_model' = True
    'path_model_to_resume': Path(""), # for 'new_vit_model' = False
    'dataset_folder': Path("C:/Users/abcd2/Downloads/dev_256/"),
    'dir_model_save': Path("./saved_model"),
    'model_file_name_prefix': 'power_law_pred_vit',
    'init_learning_rate': 1e-4,
    'test_loss_record_every_num_batch': 50,
}

# %%
train_model(CONFIG)
# Out:
# use device = cuda:0
# Number of trainable parameters: 86567656
# Number of trainable parameters: 85812498
# got fresh pretrained model = google/vit-base-patch16-224
# model cast to device = cuda:0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 16/16 [00:08<00:00,  1.91it/s]
# epoch = 0, Train:
#     loss (average per batch wise) = 9.7615e+04
#     RMS (average per batch wise) = [0.4157 0.1336 0.2411 0.249  0.222  0.2508 0.1376 0.1468 0.1116 1.8471
#  0.1439 0.1399 0.1141 0.1115 0.1106 0.109  0.155  0.1673]
# epoch = 0, Test:
#     loss (average per batch wise) = 4.7595e+04
#     RMS (average per batch wise) = [0.4106 0.1185 0.219  0.216  0.2093 0.2251 0.1219 0.1287 0.0539 1.8756
#  0.1342 0.1243 0.0699 0.0628 0.0851 0.0584 0.1272 0.1419]
# save model to saved_model/power_law_pred_vit_2022_04_22_23_25_47.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████████| 16/16 [00:06<00:00,  2.55it/s]
# epoch = 1, Train:
#     loss (average per batch wise) = 3.9507e+04
#     RMS (average per batch wise) = [0.4061 0.1415 0.2246 0.2314 0.2125 0.2276 0.1326 0.139  0.0785 1.8694
#  0.162  0.132  0.1001 0.1061 0.113  0.0848 0.1385 0.1545]
# epoch = 1, Test:
#     loss (average per batch wise) = 3.7439e+04
#     RMS (average per batch wise) = [0.4113 0.1251 0.2207 0.2259 0.2108 0.2285 0.1333 0.1393 0.0729 1.8863
#  0.1428 0.1326 0.0938 0.0981 0.0865 0.0751 0.1343 0.1381]
# save model to saved_model/power_law_pred_vit_2022_04_22_23_25_57.mdl
