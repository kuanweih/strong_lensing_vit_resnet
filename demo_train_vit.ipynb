# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - etc
#
# Note that `metadata_test.csv` and `metadata_train.csv` are generated by the following block of code
#
# ```
# import pandas as pd
# from pathlib import Path
# from sklearn.model_selection import train_test_split
#
# dir_path = Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/dev_256")
# df_meta = pd.read_csv(f"{dir_path}/metadata.csv")
# df_meta['img_name'] = df_meta['img_path'].str[-13:]
# df_train, df_test = train_test_split(df_meta, test_size=0.2)
# df_train.to_csv(f"{dir_path}/metadata_train.csv")
# df_test.to_csv(f"{dir_path}/metadata_test.csv")
# ```

# %%
from pathlib import Path
from model_vit import train_model

# %%
CONFIG = {
    'epoch': 2,
    'batch_size': 16,
    'new_vit_model': True,
    'pretrained_model_name': "google/vit-base-patch16-224", # for 'new_vit_model' = True
    'path_model_to_resume': Path(""), # for 'new_vit_model' = False
    'dataset_folder': Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/dev_256"),
    'dir_model_save': Path("./saved_model"),
    'model_file_name_prefix': 'power_law_pred_vit',
    'init_learning_rate': 1e-4,
    'test_loss_record_every_num_batch': 2,
}

# %%
train_model(CONFIG)
# Out:
# Use device = cuda:0
#
# Number of train samples = 204
# Number of test samples = 52
#
# Number of trainable parameters: 86567656
# Number of trainable parameters: 85812498
#
# Use fresh pretrained model = google/vit-base-patch16-224
#
# Model cast to device = cuda:0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:07<00:00,  1.78it/s]
# epoch = 0, Train:
#     loss (average per batch wise) = 7.2454e+04
#     RMS (average per batch wise) = [0.431  0.1912 0.2621 0.2333 0.2339 0.2604 0.1553 0.1662 0.1349 1.8224
#  0.1942 0.1708 0.1289 0.1499 0.1369 0.1114 0.162  0.1994]
# epoch = 0, Test:
#     loss (average per batch wise) = 6.5949e+04
#     RMS (average per batch wise) = [0.342  0.1282 0.1988 0.2223 0.2386 0.2547 0.1253 0.1694 0.0727 1.6793
#  0.1309 0.1236 0.0638 0.0784 0.0873 0.0659 0.1293 0.1019]
#
# Save model to saved_model/power_law_pred_vit_2022_05_01_15_15_06_testloss_6.5949e+04.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:05<00:00,  2.43it/s]
# epoch = 1, Train:
#     loss (average per batch wise) = 4.6139e+04
#     RMS (average per batch wise) = [0.4054 0.107  0.221  0.2094 0.2093 0.2175 0.1221 0.1157 0.0669 1.8524
#  0.135  0.1182 0.0564 0.0632 0.0624 0.0517 0.1138 0.127 ]
# epoch = 1, Test:
#     loss (average per batch wise) = 5.2279e+04
#     RMS (average per batch wise) = [0.3788 0.084  0.1995 0.1991 0.2395 0.2577 0.1094 0.1412 0.0519 1.7377
#  0.1095 0.1006 0.0488 0.0498 0.0463 0.0474 0.1108 0.0918]
#
# Save model to saved_model/power_law_pred_vit_2022_05_01_15_15_12_testloss_5.2279e+04.mdl
