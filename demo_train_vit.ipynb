# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - etc
#
# Note that `metadata_test.csv` and `metadata_train.csv` are generated by the following block of code
#
# ```
# import pandas as pd
# from pathlib import Path
# from sklearn.model_selection import train_test_split
#
# dir_path = Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/dev_256")
# df_meta = pd.read_csv(f"{dir_path}/metadata.csv")
# df_meta['img_name'] = df_meta['img_path'].str[-13:]
# df_train, df_test = train_test_split(df_meta, test_size=0.2)
# df_train.to_csv(f"{dir_path}/metadata_train.csv")
# df_test.to_csv(f"{dir_path}/metadata_test.csv")
# ```

# %%
from pathlib import Path
from model_vit import train_model

# %%
CONFIG = {
    'epoch': 2,
    'batch_size': 16,
    'new_vit_model': True,
    'pretrained_model_name': "google/vit-base-patch16-224", # for 'new_vit_model' = True
    'path_model_to_resume': Path(""), # for 'new_vit_model' = False
    'dataset_folder': Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/dev_256"),
    'dir_model_save': Path("./saved_model"),
    'model_file_name_prefix': 'power_law_pred_vit',
    'init_learning_rate': 1e-4,
    'test_loss_record_every_num_batch': 2,
    'target_keys': [
            "theta_E", 
            "gamma", 
            "center_x", 
            "center_y", 
            "e1", 
            "e2", 
            "gamma_ext", 
            "psi_ext", 
            "lens_light_R_sersic", 
            "lens_light_n_sersic",
        ]
}

# %%
train_model(CONFIG)
# Out:
# Use device = cuda:0
#
# Number of train samples = 204
# Number of test samples = 52
#
# Number of trainable parameters: 86567656
# Number of trainable parameters: 85806346
#
# Use fresh pretrained model = google/vit-base-patch16-224
#
# Model cast to device = cuda:0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:07<00:00,  1.74it/s]
# epoch = 0, Train:
#     loss (average per batch wise) = 7.0266e+04
#     RMS (average per batch wise) = [0.4165 0.2001 0.2629 0.2536 0.252  0.2531 0.1294 1.8637 0.2021 0.206 ]
# epoch = 0, Test:
#     loss (average per batch wise) = 4.6238e+04
#     RMS (average per batch wise) = [0.4286 0.2204 0.3426 0.3009 0.2803 0.3339 0.1524 1.7778 0.253  0.266 ]
#
# Save model to saved_model/power_law_pred_vit_2022_05_01_16_34_02_testloss_4.6238e+04.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:05<00:00,  2.37it/s]
# epoch = 1, Train:
#     loss (average per batch wise) = 4.8352e+04
#     RMS (average per batch wise) = [0.4442 0.1696 0.2825 0.2622 0.2517 0.2616 0.1506 1.8797 0.2132 0.2099]
# epoch = 1, Test:
#     loss (average per batch wise) = 6.6776e+04
#     RMS (average per batch wise) = [0.3713 0.1675 0.2916 0.2679 0.2713 0.3089 0.1101 1.7828 0.2008 0.2069]
