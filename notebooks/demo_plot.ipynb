# %%
cd ..
# Out:
# D:\GitHub\icml_2022_strong_lensing

# %%
from visualization import VisualModel
from pathlib import Path

# %%
CONFIG = {
    'epoch': 30,
    'batch_size': 30,
    'load_new_model': True,
    'new_model_name': 'google/vit-base-patch16-224' ,  # for 'load_new_model' = True
    'resumed_model_path': Path(""),  # for 'load_new_model' = False
    'output_folder': Path("D:/vit_models"),  # needs to be non-existing
    'dataset_folder': Path("D:/dev_256"),
    'init_learning_rate': 1e-3,
    'target_keys_weights': {
        "theta_E": 1, 
        "gamma": 1, 
        "center_x": 1, 
        "center_y": 1, 
        "e1": 1, 
        "e2": 1, 
        "gamma_ext": 1, 
        "psi_ext": 1, 
        "lens_light_R_sersic": 1, 
        "lens_light_n_sersic": 1,
    }
}

# %%
# !dir {CONFIG["output_folder"]}
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 655A-E0F3
#
#  Directory of D:\vit_models
#
# 05/11/2022  02:08 PM    <DIR>          .
# 05/11/2022  02:08 PM    <DIR>          ..
# 05/11/2022  09:37 AM               793 CONFIG.npy
# 05/11/2022  09:53 AM       343,421,617 epoch_0_testloss_0.351700.mdl
# 05/11/2022  11:38 AM       343,421,617 epoch_11_testloss_0.335066.mdl
# 05/11/2022  12:06 PM       343,421,617 epoch_14_testloss_0.334756.mdl
# 05/11/2022  12:25 PM       343,421,617 epoch_16_testloss_0.333571.mdl
# 05/11/2022  10:03 AM       343,421,617 epoch_1_testloss_0.338398.mdl
# 05/11/2022  02:08 PM       343,421,617 epoch_27_testloss_0.333513.mdl
# 05/11/2022  10:13 AM       343,421,617 epoch_2_testloss_0.337799.mdl
# 05/11/2022  10:22 AM       343,421,617 epoch_3_testloss_0.337469.mdl
# 05/11/2022  10:41 AM       343,421,617 epoch_5_testloss_0.336954.mdl
# 05/11/2022  10:51 AM       343,421,617 epoch_6_testloss_0.336304.mdl
# 05/11/2022  11:00 AM       343,421,617 epoch_7_testloss_0.335805.mdl
# 05/11/2022  02:27 PM             1,786 test_history.npy
# 05/11/2022  02:27 PM             1,786 train_history.npy
#               14 File(s)  3,777,642,152 bytes
#                2 Dir(s)  886,440,173,568 bytes free

# %%
model_path = "D:/vit_models/epoch_7_testloss_0.335805.mdl"
visual=VisualModel(CONFIG,model_path)
# Out:
# Use device = cuda:0
#
# Number of train samples = 24000
# Number of test samples = 6000
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:52<00:00,  3.80it/s]

# %%
visual.show_a_few_samples(2,2)
# Out:
# theta_E: truth =  1.4402, pred =  1.4302, error = -0.69 %
# e1: truth =  0.1427, pred =  0.1504, error =  5.46 %
# e2: truth = -0.2138, pred = -0.1893, error = -11.45 %
# theta_E: truth =  1.3692, pred =  1.3310, error = -2.79 %
# e1: truth =  0.4690, pred =  0.4724, error =  0.74 %
# e2: truth =  0.1326, pred =  0.1497, error =  12.88 %
# theta_E: truth =  1.2280, pred =  1.1482, error = -6.49 %
# e1: truth =  0.1000, pred =  0.0525, error = -47.52 %
# e2: truth = -0.1702, pred = -0.1389, error = -18.36 %
# theta_E: truth =  1.6330, pred =  1.7230, error =  5.51 %
# e1: truth =  0.1598, pred =  0.1713, error =  7.15 %
# e2: truth =  0.1164, pred =  0.1513, error =  30.03 %

# %%
visual.get_pred_truth_dicts()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:52<00:00,  3.82it/s]
# ({'theta_E': array([1.61464   , 1.09598315, 1.65232241, ..., 0.99483424, 1.21862829,
#          1.0118264 ]),
#   'e1': array([ 0.01335852, -0.23947823,  0.20193633, ..., -0.27247256,
#          -0.01216079,  0.07523017]),
#   'e2': array([-0.01278736,  0.10773149,  0.25837439, ..., -0.17404453,
#          -0.04858457, -0.0899827 ])},
#  {'theta_E': array([1.64607894, 1.13417864, 1.57632661, ..., 0.94395745, 1.1990068 ,
#          1.03649426]),
#   'e1': array([ 0.02132958, -0.27515438,  0.22650714, ..., -0.27451566,
#          -0.01611625,  0.06970371]),
#   'e2': array([-0.03681812,  0.08056096,  0.22813027, ..., -0.1797936 ,
#          -0.07426024, -0.10698684])})

# %%
visual.plot_each_pred_truth('e1')
