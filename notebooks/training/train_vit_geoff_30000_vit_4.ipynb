# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - X_0000002.npy
#         - etc
#
# Note that `metadata_test.csv` and `metadata_train.csv` are generated by `split_geoff_30000.ipynb`

# %%
cd ..
# Out:
# C:\Users\abcd2\OneDrive\Documents\GitHub\icml_2022_strong_lensing

# %%
from pathlib import Path

from train_model import train_model

# %%
CONFIG = {
    'epoch': 30,
    'batch_size': 30,
    'load_new_model': True,
    'new_model_name': "google/vit-base-patch16-224",  # for 'load_new_model' = True
    'resumed_model_path': Path(""),  # for 'load_new_model' = False
    'output_folder': Path("C:/Users/abcd2/Downloads/vit_4"),  # needs to be non-existing
    'dataset_folder': Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/geoff_30000"),
    'init_learning_rate': 1e-3,
    'target_keys_weights': {
        "theta_E": 1, 
        "gamma": 1, 
        "center_x": 1, 
        "center_y": 1, 
        "e1": 1, 
        "e2": 1, 
        "gamma_ext": 1, 
        "psi_ext": 1, 
        "lens_light_R_sersic": 1, 
        "lens_light_n_sersic": 1,
    }
}

# %%
train_model(CONFIG)
# Out:
# Use device = cuda:0
#
# Number of train samples = 27000
# Number of test samples = 3000
#
# Use fresh pretrained model = google/vit-base-patch16-224
#
# Number of trainable parameters: 85814036
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:02<00:00,  1.36it/s]
# train epoch = 0:  mse = 0.3752  |  rms = 1.3899
#
# test epoch = 0:  mse = 0.3488  |  rms = 1.3409
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_0_testloss_0.348782.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:02<00:00,  1.36it/s]
# train epoch = 1:  mse = 0.3474  |  rms = 1.3490
#
# test epoch = 1:  mse = 0.3416  |  rms = 1.3575
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_1_testloss_0.341630.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 2:  mse = 0.5189  |  rms = 1.5032
#
# test epoch = 2:  mse = 0.3478  |  rms = 1.3475
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 3:  mse = 0.3482  |  rms = 1.3532
#
# test epoch = 3:  mse = 0.3398  |  rms = 1.3461
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_3_testloss_0.339786.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 4:  mse = 0.3443  |  rms = 1.3544
#
# test epoch = 4:  mse = 0.3384  |  rms = 1.3519
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_4_testloss_0.338428.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 5:  mse = 0.3378  |  rms = 1.3500
#
# test epoch = 5:  mse = 0.3338  |  rms = 1.3443
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_5_testloss_0.333792.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.36it/s]
# train epoch = 6:  mse = 0.3381  |  rms = 1.3506
#
# test epoch = 6:  mse = 0.3346  |  rms = 1.3467
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 7:  mse = 0.3356  |  rms = 1.3497
#
# test epoch = 7:  mse = 0.3324  |  rms = 1.3452
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_7_testloss_0.332354.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 8:  mse = 0.3345  |  rms = 1.3492
#
# test epoch = 8:  mse = 0.3336  |  rms = 1.3414
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 9:  mse = 0.3337  |  rms = 1.3470
#
# test epoch = 9:  mse = 0.3338  |  rms = 1.3613
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 10:  mse = 0.3331  |  rms = 1.3474
#
# test epoch = 10:  mse = 0.3339  |  rms = 1.3610
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.36it/s]
# train epoch = 11:  mse = 0.3333  |  rms = 1.3514
#
# test epoch = 11:  mse = 0.3319  |  rms = 1.3557
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_11_testloss_0.331915.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.36it/s]
# train epoch = 12:  mse = 0.3327  |  rms = 1.3487
#
# test epoch = 12:  mse = 0.3308  |  rms = 1.3470
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_12_testloss_0.330766.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 13:  mse = 0.3320  |  rms = 1.3474
#
# test epoch = 13:  mse = 0.3303  |  rms = 1.3458
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_13_testloss_0.330258.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 14:  mse = 0.3319  |  rms = 1.3478
#
# test epoch = 14:  mse = 0.3303  |  rms = 1.3450
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 15:  mse = 0.3314  |  rms = 1.3454
#
# test epoch = 15:  mse = 0.3299  |  rms = 1.3493
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_15_testloss_0.329916.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:09<00:00,  1.34it/s]
# train epoch = 16:  mse = 0.3310  |  rms = 1.3462
#
# test epoch = 16:  mse = 0.3299  |  rms = 1.3470
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:06<00:00,  1.35it/s]
# train epoch = 17:  mse = 0.3312  |  rms = 1.3470
#
# test epoch = 17:  mse = 0.3298  |  rms = 1.3445
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_17_testloss_0.329773.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 18:  mse = 0.3305  |  rms = 1.3455
#
# test epoch = 18:  mse = 0.3293  |  rms = 1.3458
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_18_testloss_0.329257.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 19:  mse = 0.3307  |  rms = 1.3459
#
# test epoch = 19:  mse = 0.3302  |  rms = 1.3531
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 20:  mse = 0.3304  |  rms = 1.3451
#
# test epoch = 20:  mse = 0.3297  |  rms = 1.3486
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:08<00:00,  1.35it/s]
# train epoch = 21:  mse = 0.3302  |  rms = 1.3450
#
# test epoch = 21:  mse = 0.3291  |  rms = 1.3489
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_21_testloss_0.329095.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:05<00:00,  1.35it/s]
# train epoch = 22:  mse = 0.3301  |  rms = 1.3443
#
# test epoch = 22:  mse = 0.3293  |  rms = 1.3426
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 23:  mse = 0.3299  |  rms = 1.3451
#
# test epoch = 23:  mse = 0.3303  |  rms = 1.3503
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 24:  mse = 0.3300  |  rms = 1.3458
#
# test epoch = 24:  mse = 0.3288  |  rms = 1.3444
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_24_testloss_0.328771.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 25:  mse = 0.3297  |  rms = 1.3448
#
# test epoch = 25:  mse = 0.3293  |  rms = 1.3476
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.36it/s]
# train epoch = 26:  mse = 0.3297  |  rms = 1.3445
#
# test epoch = 26:  mse = 0.3290  |  rms = 1.3509
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 27:  mse = 0.3293  |  rms = 1.3439
#
# test epoch = 27:  mse = 0.3285  |  rms = 1.3429
#
# Save model to C:\Users\abcd2\Downloads\vit_4/epoch_27_testloss_0.328471.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:05<00:00,  1.35it/s]
# train epoch = 28:  mse = 0.3292  |  rms = 1.3438
#
# test epoch = 28:  mse = 0.3290  |  rms = 1.3456
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:05<00:00,  1.35it/s]
# train epoch = 29:  mse = 0.3293  |  rms = 1.3437
#
# test epoch = 29:  mse = 0.3286  |  rms = 1.3448

# %%
# !dir {CONFIG["output_folder"]}
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5ED1-48A8
#
#  Directory of C:\Users\abcd2\Downloads\vit_4
#
# 05/11/2022  01:51 PM    <DIR>          .
# 05/11/2022  01:51 PM    <DIR>          ..
# 05/11/2022  08:22 AM               878 CONFIG.npy
# 05/11/2022  08:34 AM       343,421,617 epoch_0_testloss_0.348782.mdl
# 05/11/2022  10:43 AM       343,421,617 epoch_11_testloss_0.331915.mdl
# 05/11/2022  10:55 AM       343,421,617 epoch_12_testloss_0.330766.mdl
# 05/11/2022  11:07 AM       343,421,617 epoch_13_testloss_0.330258.mdl
# 05/11/2022  11:30 AM       343,421,617 epoch_15_testloss_0.329916.mdl
# 05/11/2022  11:54 AM       343,421,617 epoch_17_testloss_0.329773.mdl
# 05/11/2022  12:06 PM       343,421,617 epoch_18_testloss_0.329257.mdl
# 05/11/2022  08:46 AM       343,421,617 epoch_1_testloss_0.341630.mdl
# 05/11/2022  12:41 PM       343,421,617 epoch_21_testloss_0.329095.mdl
# 05/11/2022  01:16 PM       343,421,617 epoch_24_testloss_0.328771.mdl
# 05/11/2022  01:51 PM       343,421,617 epoch_27_testloss_0.328471.mdl
# 05/11/2022  09:10 AM       343,421,617 epoch_3_testloss_0.339786.mdl
# 05/11/2022  09:21 AM       343,421,617 epoch_4_testloss_0.338428.mdl
# 05/11/2022  09:33 AM       343,421,617 epoch_5_testloss_0.333792.mdl
# 05/11/2022  09:56 AM       343,421,617 epoch_7_testloss_0.332354.mdl
# 05/11/2022  02:15 PM             1,786 test_history.npy
# 05/11/2022  02:15 PM             1,786 train_history.npy
#               18 File(s)  5,151,328,705 bytes
#                2 Dir(s)  56,949,157,888 bytes free
