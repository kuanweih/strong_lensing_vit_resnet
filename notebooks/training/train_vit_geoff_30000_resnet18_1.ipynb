# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - X_0000002.npy
#         - etc
#
# Note that `metadata_test.csv` and `metadata_train.csv` are generated by `split_geoff_30000.ipynb`

# %%
cd ..
# Out:
# C:\Users\abcd2\OneDrive\Documents\GitHub\icml_2022_strong_lensing

# %%
from pathlib import Path

from train_model import train_model

# %%
CONFIG = {
    'epoch': 30,
    'batch_size': 30,
    'load_new_model': True,
    'new_model_name': "resnet18",  # for 'load_new_model' = True
    'resumed_model_path': Path(""),  # for 'load_new_model' = False
    'output_folder': Path("C:/Users/abcd2/Downloads/resnet18_1"),  # needs to be non-existing
    'dataset_folder': Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/geoff_30000"),
    'init_learning_rate': 1e-3,
    'target_keys_weights': {
        "theta_E": 1, 
        "gamma": 1, 
        "center_x": 1, 
        "center_y": 1, 
        "e1": 1, 
        "e2": 1, 
        "gamma_ext": 1, 
        "psi_ext": 1, 
        "lens_light_R_sersic": 1, 
        "lens_light_n_sersic": 1,
    }
}

# %%
train_model(CONFIG)
# Out:
# Use device = cuda:0
#
# Number of train samples = 27000
# Number of test samples = 3000
# Using cache found in C:\Users\abcd2/.cache\torch\hub\pytorch_vision_v0.10.0
# Use fresh pretrained model = resnet18
#
# Number of trainable parameters: 11186772
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:31<00:00,  5.93it/s]
# train epoch = 0:  mse = 18.4328  |  rms = 176.6086
#
# test epoch = 0:  mse = 5771.6016  |  rms = 60697.1900
#
# Save model to C:\Users\abcd2\Downloads\resnet18_1/epoch_0_testloss_5771.601650.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:29<00:00,  6.03it/s]
# train epoch = 1:  mse = 27.9008  |  rms = 300.2007
#
# test epoch = 1:  mse = 17150.9603  |  rms = 195393.2366
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:36<00:00,  5.74it/s]
# train epoch = 2:  mse = 25.6526  |  rms = 276.6257
#
# test epoch = 2:  mse = 347568.3430  |  rms = 3890045.1204
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:36<00:00,  5.77it/s]
# train epoch = 3:  mse = 22.6875  |  rms = 252.7847
#
# test epoch = 3:  mse = 161664.4510  |  rms = 1835113.5913
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:29<00:00,  6.00it/s]
# train epoch = 4:  mse = 21.0326  |  rms = 227.7332
#
# test epoch = 4:  mse = 59669.4444  |  rms = 611742.2769
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:29<00:00,  6.01it/s]
# train epoch = 5:  mse = 17.8027  |  rms = 180.6842
#
# test epoch = 5:  mse = 3674.9038  |  rms = 38170.9631
#
# Save model to C:\Users\abcd2\Downloads\resnet18_1/epoch_5_testloss_3674.903824.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:30<00:00,  5.97it/s]
# train epoch = 6:  mse = 11.6675  |  rms = 126.1209
#
# test epoch = 6:  mse = 69322.9308  |  rms = 861807.1292
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:31<00:00,  5.94it/s]
# train epoch = 7:  mse = 8.7522  |  rms = 105.8863
#
# test epoch = 7:  mse = 1011718.4586  |  rms = 11205643.1944
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:31<00:00,  5.95it/s]
# train epoch = 8:  mse = 8.6306  |  rms = 93.2848
#
# test epoch = 8:  mse = 2086649.3728  |  rms = 22025182.4746
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:31<00:00,  5.93it/s]
# train epoch = 9:  mse = 6.7019  |  rms = 66.7269
#
# test epoch = 9:  mse = 4393726.8700  |  rms = 50398686.2013
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:31<00:00,  5.94it/s]
# train epoch = 10:  mse = 3.5492  |  rms = 41.4890
#
# test epoch = 10:  mse = 142125.9632  |  rms = 1717811.4073
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:29<00:00,  6.04it/s]
# train epoch = 11:  mse = 3.7395  |  rms = 33.2734
#
# test epoch = 11:  mse = 8245.9936  |  rms = 86746.7504
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:32<00:00,  5.91it/s]
# train epoch = 12:  mse = 1.7015  |  rms = 15.6527
#
# test epoch = 12:  mse = 8488.6102  |  rms = 135536.5907
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:32<00:00,  5.90it/s]
# train epoch = 13:  mse = 1.1998  |  rms = 10.6226
#
# test epoch = 13:  mse = 45316.4235  |  rms = 412201.7137
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:32<00:00,  5.91it/s]
# train epoch = 14:  mse = 0.9342  |  rms = 7.6994
#
# test epoch = 14:  mse = 27643.1723  |  rms = 337712.4534
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:31<00:00,  5.93it/s]
# train epoch = 15:  mse = 0.4898  |  rms = 2.4426
#
# test epoch = 15:  mse = 163053.3579  |  rms = 2594240.0373
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:30<00:00,  5.99it/s]
# train epoch = 16:  mse = 0.4245  |  rms = 2.0451
#
# test epoch = 16:  mse = 1633.2171  |  rms = 15790.3448
#
# Save model to C:\Users\abcd2\Downloads\resnet18_1/epoch_16_testloss_1633.217111.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:27<00:00,  6.09it/s]
# train epoch = 17:  mse = 0.4399  |  rms = 2.1910
#
# test epoch = 17:  mse = 2871.2565  |  rms = 30685.1893
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:27<00:00,  6.08it/s]
# train epoch = 18:  mse = 0.4792  |  rms = 2.6891
#
# test epoch = 18:  mse = 13391.3723  |  rms = 166066.6452
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:28<00:00,  6.07it/s]
# train epoch = 19:  mse = 0.7998  |  rms = 6.2644
#
# test epoch = 19:  mse = 1216.2090  |  rms = 11172.3092
#
# Save model to C:\Users\abcd2\Downloads\resnet18_1/epoch_19_testloss_1216.209019.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:29<00:00,  6.02it/s]
# train epoch = 20:  mse = 0.3958  |  rms = 1.7604
#
# test epoch = 20:  mse = 392.3208  |  rms = 4748.7277
#
# Save model to C:\Users\abcd2\Downloads\resnet18_1/epoch_20_testloss_392.320817.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:30<00:00,  5.98it/s]
# train epoch = 21:  mse = 0.3658  |  rms = 1.5112
#
# test epoch = 21:  mse = 1626.1101  |  rms = 14008.8369
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:35<00:00,  5.79it/s]
# train epoch = 22:  mse = 1.0641  |  rms = 7.3537
#
# test epoch = 22:  mse = 6343.7470  |  rms = 49874.9292
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:35<00:00,  5.80it/s]
# train epoch = 23:  mse = 0.6014  |  rms = 3.6934
#
# test epoch = 23:  mse = 991.6589  |  rms = 10513.7349
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:35<00:00,  5.77it/s]
# train epoch = 24:  mse = 1.8275  |  rms = 23.1442
#
# test epoch = 24:  mse = 201.9585  |  rms = 3407.3601
#
# Save model to C:\Users\abcd2\Downloads\resnet18_1/epoch_24_testloss_201.958541.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:35<00:00,  5.78it/s]
# train epoch = 25:  mse = 1.8314  |  rms = 25.3972
#
# test epoch = 25:  mse = 5235.4550  |  rms = 78354.8703
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:35<00:00,  5.79it/s]
# train epoch = 26:  mse = 0.9046  |  rms = 9.3231
#
# test epoch = 26:  mse = 2054.8733  |  rms = 32351.1584
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:29<00:00,  6.00it/s]
# train epoch = 27:  mse = 0.4648  |  rms = 2.5079
#
# test epoch = 27:  mse = 679.9521  |  rms = 8388.0974
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:29<00:00,  6.01it/s]
# train epoch = 28:  mse = 0.3419  |  rms = 1.3947
#
# test epoch = 28:  mse = 1209.7544  |  rms = 11034.9920
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [02:30<00:00,  5.99it/s]
# train epoch = 29:  mse = 0.3344  |  rms = 1.3542
#
# test epoch = 29:  mse = 2559.6035  |  rms = 28612.1880

# %%
# !dir {CONFIG["output_folder"]}
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5ED1-48A8
#
#  Directory of C:\Users\abcd2\Downloads\resnet18_1
#
# 05/11/2022  07:07 PM    <DIR>          .
# 05/11/2022  07:07 PM    <DIR>          ..
# 05/11/2022  05:54 PM               864 CONFIG.npy
# 05/11/2022  05:57 PM        44,833,997 epoch_0_testloss_5771.601650.mdl
# 05/11/2022  06:44 PM        44,833,997 epoch_16_testloss_1633.217111.mdl
# 05/11/2022  06:52 PM        44,833,997 epoch_19_testloss_1216.209019.mdl
# 05/11/2022  06:55 PM        44,833,997 epoch_20_testloss_392.320817.mdl
# 05/11/2022  07:07 PM        44,833,997 epoch_24_testloss_201.958541.mdl
# 05/11/2022  06:12 PM        44,833,997 epoch_5_testloss_3674.903824.mdl
# 05/11/2022  07:21 PM             1,786 test_history.npy
# 05/11/2022  07:21 PM             1,786 train_history.npy
#                9 File(s)    269,008,418 bytes
#                2 Dir(s)  56,258,113,536 bytes free
