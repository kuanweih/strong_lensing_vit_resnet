# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - X_0000002.npy
#         - etc
#
# Note that `metadata_test.csv` and `metadata_train.csv` are generated by `split_geoff_30000.ipynb`

# %%
cd ..
# Out:
# C:\Users\abcd2\OneDrive\Documents\GitHub\icml_2022_strong_lensing

# %%
from pathlib import Path

from train_model import train_model

# %%
CONFIG = {
    'epoch': 12,
    'batch_size': 30,
    'load_new_model': False,
    'new_model_name': "google/vit-base-patch16-224",  # for 'load_new_model' = True
    'resumed_model_path': Path("C:/Users/abcd2/Downloads/vit_4/epoch_27_testloss_0.328471.mdl"),  # for 'load_new_model' = False
    'output_folder': Path("C:/Users/abcd2/Downloads/vit_4_cont1"),  # needs to be non-existing
    'dataset_folder': Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/geoff_30000"),
    'init_learning_rate': 1e-3,
    'target_keys_weights': {
        "theta_E": 1, 
        "gamma": 1, 
        "center_x": 1, 
        "center_y": 1, 
        "e1": 1, 
        "e2": 1, 
        "gamma_ext": 1, 
        "psi_ext": 1, 
        "lens_light_R_sersic": 1, 
        "lens_light_n_sersic": 1,
    }
}

# %%
train_model(CONFIG)
# Out:
# Use device = cuda:0
#
# Number of train samples = 27000
# Number of test samples = 3000
#
# Use our trained model = C:\Users\abcd2\Downloads\vit_4\epoch_27_testloss_0.328471.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [10:58<00:00,  1.37it/s]
# train epoch = 0:  mse = 0.3295  |  rms = 1.3439
#
# test epoch = 0:  mse = 0.3281  |  rms = 1.3424
#
# Save model to C:\Users\abcd2\Downloads\vit_4_cont1/epoch_0_testloss_0.328098.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:03<00:00,  1.36it/s]
# train epoch = 1:  mse = 0.3295  |  rms = 1.3444
#
# test epoch = 1:  mse = 0.3292  |  rms = 1.3491
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.36it/s]
# train epoch = 2:  mse = 0.3290  |  rms = 1.3437
#
# test epoch = 2:  mse = 0.3286  |  rms = 1.3460
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 3:  mse = 0.3289  |  rms = 1.3435
#
# test epoch = 3:  mse = 0.3285  |  rms = 1.3469
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:07<00:00,  1.35it/s]
# train epoch = 4:  mse = 0.3391  |  rms = 1.3569
#
# test epoch = 4:  mse = 0.3465  |  rms = 1.3448
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 5:  mse = 0.3435  |  rms = 1.3475
#
# test epoch = 5:  mse = 0.3371  |  rms = 1.3440
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:02<00:00,  1.36it/s]
# train epoch = 6:  mse = 0.3345  |  rms = 1.3465
#
# test epoch = 6:  mse = 0.3321  |  rms = 1.3455
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:14<00:00,  1.33it/s]
# train epoch = 7:  mse = 0.3322  |  rms = 1.3462
#
# test epoch = 7:  mse = 0.3307  |  rms = 1.3434
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:04<00:00,  1.35it/s]
# train epoch = 8:  mse = 0.3317  |  rms = 1.3443
#
# test epoch = 8:  mse = 0.3299  |  rms = 1.3403
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:02<00:00,  1.36it/s]
# train epoch = 9:  mse = 0.3308  |  rms = 1.3451
#
# test epoch = 9:  mse = 0.3292  |  rms = 1.3452
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:02<00:00,  1.36it/s]
# train epoch = 10:  mse = 0.3304  |  rms = 1.3460
#
# test epoch = 10:  mse = 0.3288  |  rms = 1.3451
# 100%|████████████████████████████████████████████████████████████████████████████████| 900/900 [11:09<00:00,  1.34it/s]
# train epoch = 11:  mse = 0.3301  |  rms = 1.3449
#
# test epoch = 11:  mse = 0.3296  |  rms = 1.3493

# %%
# !dir {CONFIG["output_folder"]}
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5ED1-48A8
#
#  Directory of C:\Users\abcd2\Downloads\vit_4_cont1
#
# 05/11/2022  03:21 PM    <DIR>          .
# 05/11/2022  03:21 PM    <DIR>          ..
# 05/11/2022  03:09 PM               952 CONFIG.npy
# 05/11/2022  03:21 PM       343,422,065 epoch_0_testloss_0.328098.mdl
# 05/11/2022  05:30 PM               958 test_history.npy
# 05/11/2022  05:30 PM               958 train_history.npy
#                4 File(s)    343,424,933 bytes
#                2 Dir(s)  56,473,255,936 bytes free
