# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - etc
#
# Note that `metadata_test.csv` and `metadata_train.csv` are generated by the following block of code
#
# ```
# import pandas as pd
# from pathlib import Path
# from sklearn.model_selection import train_test_split
#
# dir_path = Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/dev_256")
# df_meta = pd.read_csv(f"{dir_path}/metadata.csv")
# df_meta['img_name'] = df_meta['img_path'].str[-13:]
# df_train, df_test = train_test_split(df_meta, test_size=0.2)
# df_train.to_csv(f"{dir_path}/metadata_train.csv")
# df_test.to_csv(f"{dir_path}/metadata_test.csv")
# ```

# %%
cd ..
# Out:
# C:\Users\abcd2\OneDrive\Documents\GitHub\icml_2022_strong_lensing

# %%
from pathlib import Path

from model_vit import train_model

# %%
from src.helpers import list_avail_model_names

list_avail_model_names()
# Out:
# ['google/vit-base-patch16-224', 'resnet18']

# %%
CONFIG = {
    'epoch': 2,
    'batch_size': 30,
    'load_new_model': True,
    'new_model_name': "google/vit-base-patch16-224",  # for 'load_new_model' = True
    'resumed_model_path': Path(""),  # for 'load_new_model' = False
    'output_folder': Path("C:/Users/abcd2/Downloads/tmp_dev_vit"),  # needs to be non-existing
    'dataset_folder': Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/dev_256"),
    'init_learning_rate': 1e-3,
    'target_keys_weights': {
        "theta_E": 10, 
        "gamma": 1, 
        "center_x": 1, 
        "center_y": 1, 
        "e1": 1, 
        "e2": 1, 
        "gamma_ext": 1, 
        "psi_ext": 1, 
        "lens_light_R_sersic": 1, 
        "lens_light_n_sersic": 1,
    }
}

# %%
train_model(CONFIG)
# Out:
# Use device = cuda:0
#
# Number of train samples = 204
# Number of test samples = 52
#
# Use fresh pretrained model = google/vit-base-patch16-224
#
# Number of trainable parameters: 85806346
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.06it/s]
# epoch = 0, train:
#     loss = 1.9500
#     err_mean = [ 0.3926 -0.9314  0.1003 -0.0063  0.0019  0.074  -0.0019 -1.3615 -0.0154
#  -0.2632]
#     err_std = [0.5041 0.2113 0.2813 0.2541 0.2672 0.2682 0.1551 1.8687 0.222  0.2306]
#
# epoch = 0, test:
#     loss = 0.3668
#     err_mean = [ 0.1994  0.0815  0.1358  0.1402 -0.0867  0.0313  0.0614 -0.1599 -0.0304
#   0.3404]
#     err_std = [0.4999 0.1782 0.2136 0.2844 0.2629 0.2708 0.1351 1.8534 0.1827 0.1932]
#
# Save model to C:\Users\abcd2\Downloads\tmp_dev_vit/epoch_0_testloss_0.366800.mdl
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:04<00:00,  1.47it/s]
# epoch = 1, train:
#     loss = 0.3413
#     err_mean = [-0.0582  0.1511 -0.0575 -0.0448 -0.0107 -0.0374 -0.0314  0.3387 -0.0572
#  -0.0102]
#     err_std = [0.4409 0.1583 0.2354 0.2208 0.2125 0.2289 0.1114 1.8044 0.1512 0.16  ]
#
# epoch = 1, test:
#     loss = 0.3514
#     err_mean = [ 0.2874  0.0385 -0.0097  0.0288  0.0118  0.0245  0.0067 -0.5765  0.1408
#  -0.2389]
#     err_std = [0.3922 0.123  0.1876 0.2404 0.2723 0.263  0.0966 1.8306 0.1454 0.1429]
#
# Save model to C:\Users\abcd2\Downloads\tmp_dev_vit/epoch_1_testloss_0.351428.mdl

# %%
# !dir {CONFIG["output_folder"]}
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5ED1-48A8
#
#  Directory of C:\Users\abcd2\Downloads\tmp_dev_vit
#
# 05/09/2022  10:18 PM    <DIR>          .
# 05/09/2022  10:18 PM    <DIR>          ..
# 05/09/2022  10:18 PM               880 CONFIG.npy
# 05/09/2022  10:18 PM       343,390,833 epoch_0_testloss_0.366800.mdl
# 05/09/2022  10:18 PM       343,390,833 epoch_1_testloss_0.351428.mdl
# 05/09/2022  10:18 PM               756 test_history.npy
# 05/09/2022  10:18 PM               756 train_history.npy
#                5 File(s)    686,784,058 bytes
#                2 Dir(s)  59,971,481,600 bytes free
