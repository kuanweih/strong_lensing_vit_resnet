# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - metadata_test_scaled.csv
#         - metadata_train_scaled.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - X_0000002.npy
#         - etc
#
# Note that `metadata_test.csv`, `metadata_train.csv`, `metadata_test_scaled.csv`, `metadata_train_scaled.csv` are generated by `split_geoff_30000.ipynb`

# %%
cd ../..
# Out:
# C:\Users\abcd2\Downloads\strong_lensing_vit_resnet

# %%
from pathlib import Path

from train_model import train_model

# %%
CONFIG = {
    "epoch": 100,
    "batch_size": 20,
    "load_new_model": True,
    'new_model_name': "google/vit-base-patch16-224",  # for 'load_new_model' = True
    # "new_model_name": "resnet152",  # for 'load_new_model' = True
    "resumed_model_path": Path(""),  # for 'load_new_model' = False
    "output_folder": Path("C:/Users/abcd2/Downloads/vit_1__lr_1em3__dp_1em1"),  # needs to be non-existing
    'dataset_folder': Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/geoff_30000"),
    "init_learning_rate": 1e-3,
    "dropout_rate": 0.1,
    "target_keys_weights": {
        "theta_E": 1, 
        "gamma": 1, 
        "center_x": 1, 
        "center_y": 1, 
        "e1": 1, 
        "e2": 1, 
        "lens_light_R_sersic": 1, 
        "lens_light_n_sersic": 1,
    }
}

# %%
train_model(CONFIG)
# Out:
# Use device = cuda:0
#
# Number of train samples = 27000
# Number of test samples = 3000
#
# Use fresh pretrained model = google/vit-base-patch16-224
#
# Number of trainable parameters: 85810960
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:59<00:00,  1.88it/s]
# train epoch = 0:  mse = 0.7272  |  rms = 1.1815
#
# test epoch = 0:  mse = 0.5243  |  rms = 1.0033
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_0_testloss_0.524261.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:53<00:00,  1.89it/s]
# train epoch = 1:  mse = 0.4516  |  rms = 0.9592
#
# test epoch = 1:  mse = 0.4022  |  rms = 0.8926
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_1_testloss_0.402167.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:51<00:00,  1.90it/s]
# train epoch = 2:  mse = 0.4162  |  rms = 0.9293
#
# test epoch = 2:  mse = 0.3849  |  rms = 0.8672
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_2_testloss_0.384867.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:45<00:00,  1.91it/s]
# train epoch = 3:  mse = 0.6044  |  rms = 1.1533
#
# test epoch = 3:  mse = 0.3670  |  rms = 0.8759
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_3_testloss_0.367022.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 4:  mse = 0.3742  |  rms = 0.8757
#
# test epoch = 4:  mse = 0.3337  |  rms = 0.8207
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_4_testloss_0.333668.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 5:  mse = 0.3359  |  rms = 0.8254
#
# test epoch = 5:  mse = 0.3187  |  rms = 0.7698
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_5_testloss_0.318668.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:44<00:00,  1.92it/s]
# train epoch = 6:  mse = 0.3161  |  rms = 0.7885
#
# test epoch = 6:  mse = 0.2930  |  rms = 0.7383
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_6_testloss_0.292977.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 7:  mse = 0.2915  |  rms = 0.7424
#
# test epoch = 7:  mse = 0.3163  |  rms = 0.7627
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 8:  mse = 0.2786  |  rms = 0.7167
#
# test epoch = 8:  mse = 0.2660  |  rms = 0.6990
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_8_testloss_0.265970.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 9:  mse = 0.2606  |  rms = 0.6785
#
# test epoch = 9:  mse = 0.3255  |  rms = 0.7835
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:44<00:00,  1.92it/s]
# train epoch = 10:  mse = 0.2665  |  rms = 0.6937
#
# test epoch = 10:  mse = 0.2763  |  rms = 0.7058
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:44<00:00,  1.92it/s]
# train epoch = 11:  mse = 0.2474  |  rms = 0.6554
#
# test epoch = 11:  mse = 0.2933  |  rms = 0.7328
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 12:  mse = 0.2351  |  rms = 0.6303
#
# test epoch = 12:  mse = 0.2837  |  rms = 0.7026
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 13:  mse = 0.2290  |  rms = 0.6135
#
# test epoch = 13:  mse = 0.3267  |  rms = 0.8244
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 14:  mse = 0.2177  |  rms = 0.5970
#
# test epoch = 14:  mse = 0.3415  |  rms = 0.8370
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:44<00:00,  1.92it/s]
# train epoch = 15:  mse = 0.2231  |  rms = 0.6023
#
# test epoch = 15:  mse = 0.2500  |  rms = 0.6912
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_15_testloss_0.250045.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 16:  mse = 0.2261  |  rms = 0.6115
#
# test epoch = 16:  mse = 0.2489  |  rms = 0.6300
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_16_testloss_0.248945.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 17:  mse = 0.2012  |  rms = 0.5603
#
# test epoch = 17:  mse = 0.2220  |  rms = 0.5805
#
# Save model to C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1/epoch_17_testloss_0.222014.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 18:  mse = 0.1952  |  rms = 0.5454
#
# test epoch = 18:  mse = 0.3150  |  rms = 0.7879
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 19:  mse = 0.1923  |  rms = 0.5356
#
# test epoch = 19:  mse = 0.2679  |  rms = 0.6512
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 20:  mse = 0.1896  |  rms = 0.5319
#
# test epoch = 20:  mse = 0.2470  |  rms = 0.6250
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 21:  mse = 0.1857  |  rms = 0.5258
#
# test epoch = 21:  mse = 0.2260  |  rms = 0.5760
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 22:  mse = 0.1783  |  rms = 0.5090
#
# test epoch = 22:  mse = 0.2845  |  rms = 0.6901
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 23:  mse = 0.1746  |  rms = 0.4985
#
# test epoch = 23:  mse = 0.2504  |  rms = 0.6943
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 24:  mse = 0.1802  |  rms = 0.5164
#
# test epoch = 24:  mse = 0.2689  |  rms = 0.7124
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 25:  mse = 0.1770  |  rms = 0.4988
#
# test epoch = 25:  mse = 0.2438  |  rms = 0.6626
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 26:  mse = 0.1640  |  rms = 0.4731
#
# test epoch = 26:  mse = 0.2349  |  rms = 0.6109
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 27:  mse = 0.1592  |  rms = 0.4598
#
# test epoch = 27:  mse = 0.2726  |  rms = 0.7250
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 28:  mse = 0.1545  |  rms = 0.4482
#
# test epoch = 28:  mse = 0.3006  |  rms = 0.8159
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 29:  mse = 0.1520  |  rms = 0.4427
#
# test epoch = 29:  mse = 0.2778  |  rms = 0.7086
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 30:  mse = 0.1532  |  rms = 0.4408
#
# test epoch = 30:  mse = 0.2759  |  rms = 0.7225
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:44<00:00,  1.92it/s]
# train epoch = 31:  mse = 0.1442  |  rms = 0.4205
#
# test epoch = 31:  mse = 0.3127  |  rms = 0.7432
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 32:  mse = 0.1407  |  rms = 0.4132
#
# test epoch = 32:  mse = 0.2770  |  rms = 0.6981
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 33:  mse = 0.1441  |  rms = 0.4236
#
# test epoch = 33:  mse = 0.2244  |  rms = 0.5772
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 34:  mse = 0.1414  |  rms = 0.4164
#
# test epoch = 34:  mse = 0.2983  |  rms = 0.7432
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 35:  mse = 0.1571  |  rms = 0.4486
#
# test epoch = 35:  mse = 0.2984  |  rms = 0.7370
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 36:  mse = 0.1357  |  rms = 0.4013
#
# test epoch = 36:  mse = 0.2403  |  rms = 0.6172
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 37:  mse = 0.1408  |  rms = 0.4141
#
# test epoch = 37:  mse = 0.2649  |  rms = 0.6297
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 38:  mse = 0.1305  |  rms = 0.3875
#
# test epoch = 38:  mse = 0.3718  |  rms = 0.9508
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 39:  mse = 0.1261  |  rms = 0.3746
#
# test epoch = 39:  mse = 0.2790  |  rms = 0.6756
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 40:  mse = 0.1260  |  rms = 0.3742
#
# test epoch = 40:  mse = 0.2926  |  rms = 0.7229
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 41:  mse = 0.1265  |  rms = 0.3758
#
# test epoch = 41:  mse = 0.3202  |  rms = 0.8098
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 42:  mse = 0.1207  |  rms = 0.3592
#
# test epoch = 42:  mse = 0.2477  |  rms = 0.5958
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 43:  mse = 0.1180  |  rms = 0.3551
#
# test epoch = 43:  mse = 0.3179  |  rms = 0.8277
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 44:  mse = 0.1171  |  rms = 0.3518
#
# test epoch = 44:  mse = 0.3294  |  rms = 0.8016
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:43<00:00,  1.92it/s]
# train epoch = 45:  mse = 0.1142  |  rms = 0.3443
#
# test epoch = 45:  mse = 0.3148  |  rms = 0.7694
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:45<00:00,  1.91it/s]
# train epoch = 46:  mse = 0.1112  |  rms = 0.3342
#
# test epoch = 46:  mse = 0.3098  |  rms = 0.7778
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:56<00:00,  1.89it/s]
# train epoch = 47:  mse = 0.1102  |  rms = 0.3358
#
# test epoch = 47:  mse = 0.3248  |  rms = 0.8296
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [12:04<00:00,  1.86it/s]
# train epoch = 48:  mse = 0.1138  |  rms = 0.3437
#
# test epoch = 48:  mse = 0.3563  |  rms = 0.9153
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:57<00:00,  1.88it/s]
# train epoch = 49:  mse = 0.1064  |  rms = 0.3218
#
# test epoch = 49:  mse = 0.3725  |  rms = 0.9559
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:50<00:00,  1.90it/s]
# train epoch = 50:  mse = 0.1052  |  rms = 0.3215
#
# test epoch = 50:  mse = 0.2647  |  rms = 0.6555
#   4%|███▏                                                                            | 54/1350 [00:28<11:33,  1.87it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5844/3568855926.py in <module>
# ----> 1 train_model(CONFIG)
#
# ~\Downloads\strong_lensing_vit_resnet\train_model.py in train_model(CONFIG)
#     221
#     222         for data, target_dict in tqdm(train_loader, total=len(train_loader)):
# --> 223             data, target = prepare_data_and_target(data, target_dict, device)
#     224             optimizer.zero_grad()
#     225             pred_mu, pred_logvar = calc_pred(model, data)
#
# ~\Downloads\strong_lensing_vit_resnet\train_model.py in prepare_data_and_target(data, target_dict, device)
#      46         target (torch.Tensor): targets(Y)
#      47     """
# ---> 48     data = data.float().to(device)
#      49     for key, val in target_dict.items():
#      50         target_dict[key] = val.float().to(device)
#
# KeyboardInterrupt:

# %%
# !dir {CONFIG["output_folder"]}
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5ED1-48A8
#
#  Directory of C:\Users\abcd2\Downloads\vit_1__lr_1em3__dp_1em1
#
# 07/07/2022  02:43 AM    <DIR>          .
# 07/07/2022  02:43 AM    <DIR>          ..
# 07/06/2022  10:59 PM               890 CONFIG.npy
# 07/06/2022  11:12 PM       343,409,265 epoch_0_testloss_0.524261.mdl
# 07/07/2022  02:18 AM       343,409,265 epoch_15_testloss_0.250045.mdl
# 07/07/2022  02:31 AM       343,409,265 epoch_16_testloss_0.248945.mdl
# 07/07/2022  02:43 AM       343,409,265 epoch_17_testloss_0.222014.mdl
# 07/06/2022  11:25 PM       343,409,265 epoch_1_testloss_0.402167.mdl
# 07/06/2022  11:37 PM       343,409,265 epoch_2_testloss_0.384867.mdl
# 07/06/2022  11:50 PM       343,409,265 epoch_3_testloss_0.367022.mdl
# 07/07/2022  12:02 AM       343,409,265 epoch_4_testloss_0.333668.mdl
# 07/07/2022  12:15 AM       343,409,265 epoch_5_testloss_0.318668.mdl
# 07/07/2022  12:27 AM       343,409,265 epoch_6_testloss_0.292977.mdl
# 07/07/2022  12:52 AM       343,409,265 epoch_8_testloss_0.265970.mdl
# 07/07/2022  09:32 AM             2,983 test_history.npy
# 07/07/2022  09:32 AM             2,983 train_history.npy
#               14 File(s)  3,777,508,771 bytes
#                2 Dir(s)  25,506,443,264 bytes free
