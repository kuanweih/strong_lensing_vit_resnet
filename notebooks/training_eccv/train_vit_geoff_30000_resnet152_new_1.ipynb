# %% [markdown]
# Make sure datatset is saved as:
#
#     - data_folder:
#         - metadata.csv
#         - metadata_test.csv
#         - metadata_train.csv
#         - metadata_test_scaled.csv
#         - metadata_train_scaled.csv
#         - X_0000000.npy
#         - X_0000001.npy
#         - X_0000002.npy
#         - etc
#
# Note that `metadata_test.csv`, `metadata_train.csv`, `metadata_test_scaled.csv`, `metadata_train_scaled.csv` are generated by `split_geoff_30000.ipynb`

# %%
cd ../..
# Out:
# C:\Users\abcd2\Downloads\strong_lensing_vit_resnet

# %%
from pathlib import Path

from train_model import train_model

# %%
CONFIG = {
    "epoch": 100,
    "batch_size": 20,
    "load_new_model": True,
#     'new_model_name': "google/vit-base-patch16-224",  # for 'load_new_model' = True
    "new_model_name": "resnet152",  # for 'load_new_model' = True
    "resumed_model_path": Path(""),  # for 'load_new_model' = False
    "output_folder": Path("C:/Users/abcd2/Downloads/resnet152_1__lr_1em3__dp_1em1"),  # needs to be non-existing
    'dataset_folder': Path("C:/Users/abcd2/Datasets/2022_icml_lens_sim/geoff_30000"),
    "init_learning_rate": 1e-3,
    "dropout_rate": 0.1,
    "target_keys_weights": {
        "theta_E": 1, 
        "gamma": 1, 
        "center_x": 1, 
        "center_y": 1, 
        "e1": 1, 
        "e2": 1, 
        "lens_light_R_sersic": 1, 
        "lens_light_n_sersic": 1,
    }
}

# %%
train_model(CONFIG)
# Out:
# Use device = cuda:0
#
# Number of train samples = 27000
# Number of test samples = 3000
# Using cache found in C:\Users\abcd2/.cache\torch\hub\pytorch_vision_v0.10.0
# Use fresh pretrained model = resnet152
#
# Number of trainable parameters: 58176592
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:31<00:00,  2.14it/s]
# train epoch = 0:  mse = 1.0061  |  rms = 1.4310
#
# test epoch = 0:  mse = 0.8652  |  rms = 1.3678
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_0_testloss_0.865212.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:04<00:00,  2.03it/s]
# train epoch = 1:  mse = 0.7797  |  rms = 1.2329
#
# test epoch = 1:  mse = 0.7277  |  rms = 1.2285
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_1_testloss_0.727729.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:14<00:00,  2.20it/s]
# train epoch = 2:  mse = 0.7221  |  rms = 1.2053
#
# test epoch = 2:  mse = 0.7070  |  rms = 1.2099
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_2_testloss_0.707039.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:14<00:00,  2.20it/s]
# train epoch = 3:  mse = 0.7011  |  rms = 1.2015
#
# test epoch = 3:  mse = 0.8121  |  rms = 1.8741
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:27<00:00,  2.15it/s]
# train epoch = 4:  mse = 0.6881  |  rms = 1.2000
#
# test epoch = 4:  mse = 0.7361  |  rms = 1.5877
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:12<00:00,  2.20it/s]
# train epoch = 5:  mse = 0.6787  |  rms = 1.1979
#
# test epoch = 5:  mse = 0.6567  |  rms = 1.1754
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_5_testloss_0.656738.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:10<00:00,  2.21it/s]
# train epoch = 6:  mse = 0.6685  |  rms = 1.1934
#
# test epoch = 6:  mse = 0.8112  |  rms = 2.2143
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:10<00:00,  2.21it/s]
# train epoch = 7:  mse = 0.6611  |  rms = 1.1905
#
# test epoch = 7:  mse = 0.8657  |  rms = 2.4032
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:09<00:00,  2.22it/s]
# train epoch = 8:  mse = 0.6499  |  rms = 1.1822
#
# test epoch = 8:  mse = 0.7523  |  rms = 2.3568
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:11<00:00,  2.21it/s]
# train epoch = 9:  mse = 0.6385  |  rms = 1.1731
#
# test epoch = 9:  mse = 0.6701  |  rms = 1.4081
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:11<00:00,  2.21it/s]
# train epoch = 10:  mse = 0.6262  |  rms = 1.1619
#
# test epoch = 10:  mse = 0.6298  |  rms = 1.2113
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_10_testloss_0.629820.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:24<00:00,  2.16it/s]
# train epoch = 11:  mse = 0.6159  |  rms = 1.1539
#
# test epoch = 11:  mse = 0.6352  |  rms = 1.4397
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 12:  mse = 0.6066  |  rms = 1.1442
#
# test epoch = 12:  mse = 0.6344  |  rms = 1.1747
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 13:  mse = 0.5987  |  rms = 1.1396
#
# test epoch = 13:  mse = 0.5809  |  rms = 1.1521
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_13_testloss_0.580851.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:12<00:00,  2.20it/s]
# train epoch = 14:  mse = 0.5934  |  rms = 1.1353
#
# test epoch = 14:  mse = 0.6164  |  rms = 1.1834
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:12<00:00,  2.20it/s]
# train epoch = 15:  mse = 0.5877  |  rms = 1.1304
#
# test epoch = 15:  mse = 0.5687  |  rms = 1.1127
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_15_testloss_0.568688.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:11<00:00,  2.21it/s]
# train epoch = 16:  mse = 0.5801  |  rms = 1.1227
#
# test epoch = 16:  mse = 0.5649  |  rms = 1.1202
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_16_testloss_0.564858.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 17:  mse = 0.5753  |  rms = 1.1193
#
# test epoch = 17:  mse = 0.6810  |  rms = 1.1775
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.19it/s]
# train epoch = 18:  mse = 0.5716  |  rms = 1.1160
#
# test epoch = 18:  mse = 0.5582  |  rms = 1.1110
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_18_testloss_0.558193.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.19it/s]
# train epoch = 19:  mse = 0.5684  |  rms = 1.1126
#
# test epoch = 19:  mse = 0.6076  |  rms = 1.1158
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.19it/s]
# train epoch = 20:  mse = 0.5642  |  rms = 1.1073
#
# test epoch = 20:  mse = 0.5605  |  rms = 1.1041
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:14<00:00,  2.20it/s]
# train epoch = 21:  mse = 0.5608  |  rms = 1.1049
#
# test epoch = 21:  mse = 0.5860  |  rms = 1.1092
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.19it/s]
# train epoch = 22:  mse = 0.5585  |  rms = 1.1040
#
# test epoch = 22:  mse = 0.5433  |  rms = 1.0954
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_22_testloss_0.543285.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 23:  mse = 0.5553  |  rms = 1.0995
#
# test epoch = 23:  mse = 0.5546  |  rms = 1.0956
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.19it/s]
# train epoch = 24:  mse = 0.5509  |  rms = 1.0940
#
# test epoch = 24:  mse = 0.5490  |  rms = 1.0865
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 25:  mse = 0.5483  |  rms = 1.0889
#
# test epoch = 25:  mse = 0.5469  |  rms = 1.0813
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:26<00:00,  2.16it/s]
# train epoch = 26:  mse = 0.5469  |  rms = 1.0887
#
# test epoch = 26:  mse = 0.5488  |  rms = 1.0854
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.19it/s]
# train epoch = 27:  mse = 0.5421  |  rms = 1.0813
#
# test epoch = 27:  mse = 0.5443  |  rms = 1.0750
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.19it/s]
# train epoch = 28:  mse = 0.5407  |  rms = 1.0804
#
# test epoch = 28:  mse = 0.5309  |  rms = 1.0754
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_28_testloss_0.530949.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:09<00:00,  2.22it/s]
# train epoch = 29:  mse = 0.5369  |  rms = 1.0756
#
# test epoch = 29:  mse = 0.5604  |  rms = 1.0917
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:08<00:00,  2.22it/s]
# train epoch = 30:  mse = 0.5343  |  rms = 1.0711
#
# test epoch = 30:  mse = 0.5695  |  rms = 1.0840
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 31:  mse = 0.5313  |  rms = 1.0655
#
# test epoch = 31:  mse = 0.5263  |  rms = 1.0619
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_31_testloss_0.526321.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:04<00:00,  2.03it/s]
# train epoch = 32:  mse = 0.5292  |  rms = 1.0658
#
# test epoch = 32:  mse = 0.5353  |  rms = 1.0644
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:43<00:00,  2.10it/s]
# train epoch = 33:  mse = 0.5255  |  rms = 1.0595
#
# test epoch = 33:  mse = 0.5541  |  rms = 1.0757
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:43<00:00,  2.10it/s]
# train epoch = 34:  mse = 0.5215  |  rms = 1.0511
#
# test epoch = 34:  mse = 0.5338  |  rms = 1.0578
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:56<00:00,  2.06it/s]
# train epoch = 35:  mse = 0.5177  |  rms = 1.0458
#
# test epoch = 35:  mse = 0.5424  |  rms = 1.0570
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:46<00:00,  2.09it/s]
# train epoch = 36:  mse = 0.5157  |  rms = 1.0456
#
# test epoch = 36:  mse = 0.5214  |  rms = 1.0501
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_36_testloss_0.521375.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:12<00:00,  2.20it/s]
# train epoch = 37:  mse = 0.5124  |  rms = 1.0398
#
# test epoch = 37:  mse = 0.6518  |  rms = 1.1435
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:09<00:00,  2.21it/s]
# train epoch = 38:  mse = 0.5097  |  rms = 1.0374
#
# test epoch = 38:  mse = 0.5224  |  rms = 1.0350
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:09<00:00,  2.22it/s]
# train epoch = 39:  mse = 0.5056  |  rms = 1.0299
#
# test epoch = 39:  mse = 0.5378  |  rms = 1.0428
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 40:  mse = 0.5027  |  rms = 1.0260
#
# test epoch = 40:  mse = 0.5348  |  rms = 1.0405
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 41:  mse = 0.4993  |  rms = 1.0212
#
# test epoch = 41:  mse = 0.5660  |  rms = 1.0609
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:10<00:00,  2.21it/s]
# train epoch = 42:  mse = 0.4985  |  rms = 1.0211
#
# test epoch = 42:  mse = 0.5298  |  rms = 1.0383
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:09<00:00,  2.21it/s]
# train epoch = 43:  mse = 0.4936  |  rms = 1.0138
#
# test epoch = 43:  mse = 0.5007  |  rms = 1.0154
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_43_testloss_0.500730.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:08<00:00,  2.22it/s]
# train epoch = 44:  mse = 0.4908  |  rms = 1.0101
#
# test epoch = 44:  mse = 0.4945  |  rms = 1.0158
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_44_testloss_0.494502.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:06<00:00,  2.23it/s]
# train epoch = 45:  mse = 0.4888  |  rms = 1.0075
#
# test epoch = 45:  mse = 0.4945  |  rms = 1.0086
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_45_testloss_0.494487.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.20it/s]
# train epoch = 46:  mse = 0.4852  |  rms = 1.0050
#
# test epoch = 46:  mse = 0.5201  |  rms = 1.0320
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [12:06<00:00,  1.86it/s]
# train epoch = 47:  mse = 0.4838  |  rms = 1.0005
#
# test epoch = 47:  mse = 0.5000  |  rms = 1.0123
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [12:35<00:00,  1.79it/s]
# train epoch = 48:  mse = 0.4796  |  rms = 0.9941
#
# test epoch = 48:  mse = 0.5160  |  rms = 1.0152
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:46<00:00,  2.09it/s]
# train epoch = 49:  mse = 0.4759  |  rms = 0.9882
#
# test epoch = 49:  mse = 0.5447  |  rms = 1.0618
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:43<00:00,  2.10it/s]
# train epoch = 50:  mse = 0.4764  |  rms = 0.9910
#
# test epoch = 50:  mse = 0.5254  |  rms = 1.0364
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:47<00:00,  2.08it/s]
# train epoch = 51:  mse = 0.4731  |  rms = 0.9869
#
# test epoch = 51:  mse = 0.4830  |  rms = 1.0008
#
# Save model to C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1/epoch_51_testloss_0.483049.mdl
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 52:  mse = 0.4712  |  rms = 0.9821
#
# test epoch = 52:  mse = 0.5983  |  rms = 1.1030
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:14<00:00,  2.20it/s]
# train epoch = 53:  mse = 0.4694  |  rms = 0.9806
#
# test epoch = 53:  mse = 0.5030  |  rms = 1.0125
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:14<00:00,  2.20it/s]
# train epoch = 54:  mse = 0.4672  |  rms = 0.9790
#
# test epoch = 54:  mse = 0.6805  |  rms = 1.2215
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:12<00:00,  2.20it/s]
# train epoch = 55:  mse = 0.4651  |  rms = 0.9746
#
# test epoch = 55:  mse = 0.4974  |  rms = 1.0129
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:14<00:00,  2.20it/s]
# train epoch = 56:  mse = 0.4629  |  rms = 0.9735
#
# test epoch = 56:  mse = 0.5914  |  rms = 1.1166
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:14<00:00,  2.20it/s]
# train epoch = 57:  mse = 0.4601  |  rms = 0.9714
#
# test epoch = 57:  mse = 0.5140  |  rms = 1.0231
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:11<00:00,  2.21it/s]
# train epoch = 58:  mse = 0.4592  |  rms = 0.9668
#
# test epoch = 58:  mse = 0.8411  |  rms = 1.4169
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:05<00:00,  2.23it/s]
# train epoch = 59:  mse = 0.4578  |  rms = 0.9663
#
# test epoch = 59:  mse = 0.5392  |  rms = 1.0393
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:03<00:00,  2.24it/s]
# train epoch = 60:  mse = 0.4547  |  rms = 0.9645
#
# test epoch = 60:  mse = 0.4950  |  rms = 1.0142
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:06<00:00,  2.23it/s]
# train epoch = 61:  mse = 0.4526  |  rms = 0.9615
#
# test epoch = 61:  mse = 0.6545  |  rms = 1.1679
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:42<00:00,  2.10it/s]
# train epoch = 62:  mse = 0.4507  |  rms = 0.9572
#
# test epoch = 62:  mse = 0.7528  |  rms = 1.2966
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:15<00:00,  2.19it/s]
# train epoch = 63:  mse = 0.4496  |  rms = 0.9561
#
# test epoch = 63:  mse = 0.5222  |  rms = 1.0286
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:21<00:00,  2.17it/s]
# train epoch = 64:  mse = 0.4482  |  rms = 0.9548
#
# test epoch = 64:  mse = 0.5560  |  rms = 1.0663
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:40<00:00,  2.11it/s]
# train epoch = 65:  mse = 0.4476  |  rms = 0.9540
#
# test epoch = 65:  mse = 0.5184  |  rms = 1.0218
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:18<00:00,  1.99it/s]
# train epoch = 66:  mse = 0.4456  |  rms = 0.9510
#
# test epoch = 66:  mse = 0.5052  |  rms = 1.0160
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:50<00:00,  2.07it/s]
# train epoch = 67:  mse = 0.4443  |  rms = 0.9520
#
# test epoch = 67:  mse = 0.5798  |  rms = 1.0916
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:17<00:00,  2.19it/s]
# train epoch = 68:  mse = 0.4430  |  rms = 0.9475
#
# test epoch = 68:  mse = 0.5201  |  rms = 1.0386
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:13<00:00,  2.20it/s]
# train epoch = 69:  mse = 0.4408  |  rms = 0.9452
#
# test epoch = 69:  mse = 0.5142  |  rms = 1.0191
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:10<00:00,  2.21it/s]
# train epoch = 70:  mse = 0.4398  |  rms = 0.9438
#
# test epoch = 70:  mse = 0.4878  |  rms = 0.9967
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:39<00:00,  2.11it/s]
# train epoch = 71:  mse = 0.4382  |  rms = 0.9443
#
# test epoch = 71:  mse = 0.5291  |  rms = 1.0264
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [11:36<00:00,  1.94it/s]
# train epoch = 72:  mse = 0.4374  |  rms = 0.9418
#
# test epoch = 72:  mse = 0.5130  |  rms = 1.0305
# 100%|██████████████████████████████████████████████████████████████████████████████| 1350/1350 [10:41<00:00,  2.10it/s]
# train epoch = 73:  mse = 0.4346  |  rms = 0.9387
#
# test epoch = 73:  mse = 0.5564  |  rms = 1.0678
#  27%|█████████████████████                                                          | 360/1350 [02:55<08:01,  2.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4456/3568855926.py in <module>
# ----> 1 train_model(CONFIG)
#
# ~\Downloads\strong_lensing_vit_resnet\train_model.py in train_model(CONFIG)
#     220         cache_train = CacheEpoch("train")
#     221
# --> 222         for data, target_dict in tqdm(train_loader, total=len(train_loader)):
#     223             data, target = prepare_data_and_target(data, target_dict, device)
#     224             optimizer.zero_grad()
#
# ~\anaconda3\lib\site-packages\tqdm\std.py in __iter__(self)
#    1178
#    1179         try:
# -> 1180             for obj in iterable:
#    1181                 yield obj
#    1182                 # Update and possibly print the progressbar.
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# ~\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
# ---> 52         return self.collate_fn(data)
#
# ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in default_collate(batch)
#      82             raise RuntimeError('each element in list of batch should be of equal size')
#      83         transposed = zip(*batch)
# ---> 84         return [default_collate(samples) for samples in transposed]
#      85
#      86     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in <listcomp>(.0)
#      82             raise RuntimeError('each element in list of batch should be of equal size')
#      83         transposed = zip(*batch)
# ---> 84         return [default_collate(samples) for samples in transposed]
#      85
#      86     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in default_collate(batch)
#      62                 raise TypeError(default_collate_err_msg_format.format(elem.dtype))
#      63
# ---> 64             return default_collate([torch.as_tensor(b) for b in batch])
#      65         elif elem.shape == ():  # scalars
#      66             return torch.as_tensor(batch)
#
# ~\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in default_collate(batch)
#      54             storage = elem.storage()._new_shared(numel)
#      55             out = elem.new(storage)
# ---> 56         return torch.stack(batch, 0, out=out)
#      57     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#      58             and elem_type.__name__ != 'string_':
#
# KeyboardInterrupt:

# %%
# !dir {CONFIG["output_folder"]}
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5ED1-48A8
#
#  Directory of C:\Users\abcd2\Downloads\resnet152_1__lr_1em3__dp_1em1
#
# 07/07/2022  07:09 PM    <DIR>          .
# 07/07/2022  07:09 PM    <DIR>          ..
# 07/07/2022  09:39 AM               878 CONFIG.npy
# 07/07/2022  09:50 AM       233,681,657 epoch_0_testloss_0.865212.mdl
# 07/07/2022  11:38 AM       233,681,657 epoch_10_testloss_0.629820.mdl
# 07/07/2022  12:11 PM       233,681,657 epoch_13_testloss_0.580851.mdl
# 07/07/2022  12:32 PM       233,681,657 epoch_15_testloss_0.568688.mdl
# 07/07/2022  12:43 PM       233,681,657 epoch_16_testloss_0.564858.mdl
# 07/07/2022  01:04 PM       233,681,657 epoch_18_testloss_0.558193.mdl
# 07/07/2022  10:01 AM       233,681,657 epoch_1_testloss_0.727729.mdl
# 07/07/2022  01:47 PM       233,681,657 epoch_22_testloss_0.543285.mdl
# 07/07/2022  02:52 PM       233,681,657 epoch_28_testloss_0.530949.mdl
# 07/07/2022  10:12 AM       233,681,657 epoch_2_testloss_0.707039.mdl
# 07/07/2022  03:24 PM       233,681,657 epoch_31_testloss_0.526321.mdl
# 07/07/2022  04:21 PM       233,681,657 epoch_36_testloss_0.521375.mdl
# 07/07/2022  05:36 PM       233,681,657 epoch_43_testloss_0.500730.mdl
# 07/07/2022  05:47 PM       233,681,657 epoch_44_testloss_0.494502.mdl
# 07/07/2022  05:58 PM       233,681,657 epoch_45_testloss_0.494487.mdl
# 07/07/2022  07:09 PM       233,681,657 epoch_51_testloss_0.483049.mdl
# 07/07/2022  10:45 AM       233,681,657 epoch_5_testloss_0.656738.mdl
# 07/07/2022  11:10 PM             4,455 test_history.npy
# 07/07/2022  11:10 PM             4,455 train_history.npy
#               20 File(s)  3,972,597,957 bytes
#                2 Dir(s)  25,287,917,568 bytes free
